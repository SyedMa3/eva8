# %%
# !git clone https://github.com/SyedMa3/eva8.git
# %cd eva8/session-12/yolov3
# Out:
# Cloning into 'eva8'...
# remote: Enumerating objects: 510, done.
# remote: Counting objects: 100% (510/510), done.
# remote: Compressing objects: 100% (464/464), done.
# remote: Total 510 (delta 62), reused 462 (delta 31), pack-reused 0
# Receiving objects: 100% (510/510), 3.29 MiB | 4.25 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# /content/eva8/session-12/yolov3

# %% [markdown]
# # Training

# %%
# !gdown 1vRDkpAiNdqHORTUImkrpD7kK_DkCcMus
# !mkdir weights
# %mv yolov3-spp-ultralytics.pt weights/yolov3-spp-ultralytics.pt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vRDkpAiNdqHORTUImkrpD7kK_DkCcMus
# To: /content/eva8/session-12/yolov3/yolov3-spp-ultralytics.pt
# 100% 252M/252M [00:01<00:00, 249MB/s]

# %%
# !python train.py --data data/customdata/custom.data --batch 16 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --resume
# Out:
# Namespace(epochs=300, batch_size=16, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=True, nosave=False, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/last.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# 2023-04-04 12:40:17.757575: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 12:40:18.711252: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# WARNING: smart bias initialization failure.
# ...

# %%
# !python detect.py
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='data/customdata/images', output='output', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/123 data/customdata/images/a1.jpg: 512x256 1 astrids, Done. (0.041s)
# image 2/123 data/customdata/images/a10.jpg: 320x512 1 hiccupss, 1 astrids, Done. (0.044s)
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %mv weights/best.pt /content/gdrive/MyDrive/eva/best.pt

# %% [markdown]
# # Testing

# %%
# !gdown 17PNQBtk0sDeyrYQKZ9IGvTUXQCX61ieW
# !mkdir weights
# %mv best.pt weights/last.pt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17PNQBtk0sDeyrYQKZ9IGvTUXQCX61ieW
# To: /content/eva8/session-12/yolov3/best.pt
# 100% 501M/501M [00:03<00:00, 151MB/s]

# %%
# !gdown 1vdHfcxCWnipfqWePL-hDpNCzFODI9S1D
# !unzip vid.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vdHfcxCWnipfqWePL-hDpNCzFODI9S1D
# To: /content/eva8/session-12/yolov3/vid.zip
# 100% 25.5M/25.5M [00:00<00:00, 28.9MB/s]
# Archive:  vid.zip
#    creating: vid/
#   inflating: vid/0003.jpg
#   inflating: vid/0005.jpg
#   inflating: vid/0006.jpg
#   inflating: vid/0008.jpg
#   inflating: vid/0009.jpg
#   inflating: vid/0010.jpg
#   inflating: vid/0012.jpg
#   inflating: vid/0013.jpg
#   inflating: vid/0014.jpg
#   inflating: vid/0018.jpg
#   inflating: vid/0020.jpg
#   inflating: vid/0021.jpg
#   inflating: vid/0022.jpg
#   inflating: vid/0026.jpg
#   inflating: vid/0027.jpg
#   inflating: vid/0028.jpg
#   inflating: vid/0031.jpg
#   inflating: vid/0036.jpg
#   inflating: vid/0037.jpg
#   inflating: vid/0040.jpg
#   inflating: vid/0044.jpg
#   inflating: vid/0049.jpg
#   inflating: vid/0050.jpg
#   inflating: vid/0053.jpg
#   inflating: vid/0055.jpg
#   inflating: vid/0057.jpg
#   inflating: vid/0063.jpg
# ...

# %%
# !python detect.py --conf-thres 0.3 --output vid-output/ --source vid/
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='vid/', output='vid-output/', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/3036 vid/0001.jpg: 320x512 Done. (0.040s)
# image 2/3036 vid/0002.jpg: 320x512 Done. (0.030s)
# image 3/3036 vid/0003.jpg: 320x512 Done. (0.030s)
# image 4/3036 vid/0004.jpg: 320x512 Done. (0.030s)
# ...

# %%
# !ffmpeg -i 'vid-output/%04d.jpg' output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# !python detect.py --conf-thres 0.3 --output 16-output --source 16-img/
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='16-img/', output='16-output', img_size=512, conf_thres=0.3, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15101MB)
#
# Model Summary: 225 layers, 6.25949e+07 parameters, 6.25949e+07 gradients
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/16 16-img/a1.jpg: 512x384 1 astrids, Done. (0.044s)
# image 2/16 16-img/a2.jpeg: 512x256 1 astrids, Done. (0.042s)
# image 3/16 16-img/a3.jpeg: 256x512 1 hiccupss, 1 astrids, Done. (0.038s)
# ...

# %%
# !zip -r 16-output.zip 16-output/
# Out:
#   adding: 16-output/ (stored 0%)
#   adding: 16-output/t1.jpg (deflated 6%)
#   adding: 16-output/t4.jpg (deflated 3%)
#   adding: 16-output/a4.jpeg (deflated 6%)
#   adding: 16-output/e4.jpeg (deflated 8%)
#   adding: 16-output/t3.jpg (deflated 7%)
#   adding: 16-output/e3.jpeg (deflated 10%)
#   adding: 16-output/a2.jpeg (deflated 10%)
#   adding: 16-output/e2.jpeg (deflated 6%)
#   adding: 16-output/t2.jpg (deflated 0%)
#   adding: 16-output/a3.jpeg (deflated 4%)
#   adding: 16-output/e1.jpg (deflated 23%)
#   adding: 16-output/a1.jpg (deflated 7%)
#   adding: 16-output/h4.jpg (deflated 6%)
#   adding: 16-output/h1.jpg (deflated 8%)
#   adding: 16-output/h2.jpg (deflated 7%)
#   adding: 16-output/h3.jpg (deflated 5%)
